# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_hr = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df_hr #Частично выведем датасет на экран
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
pd.options.display.max_columns = 999
df_hr # Вывожу все стобцы и смотрю, какие данные у нас здесь вообще есть. Демографические -  пол и возраст, семейное положение + образование; информация о долдности, ртациях и стаже работы; несколько столбцов с информацией об оплате труда; результаты опросов, свзанных с субъективным благополучием сотрудников.
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_hr.info() # Проверим датасет на наличие пропущенных значений. Так как их нет, делаем вывод, что данные уже прошли чистку и готовы к обработке
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int64
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# В данном датасете есть два, как мне кажется, важных столбца с бинарными значениями (attrition и gender), которые записаны буквами, их можно переписать для удобства

# %%
#df_hr['Attrition'] = df_hr['Attrition'].map({'No': 1, 'Yes': 0})
df_hr.Attrition.replace(['No','Yes'],[1,0],inplace=True)
df_hr.Gender.replace(['Male','Female'],[1,0],inplace=True)
df_hr
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          0      Travel_Rarely       1102                   Sales
# 1      49          1  Travel_Frequently        279  Research & Development
# 2      37          0      Travel_Rarely       1373  Research & Development
# 3      33          1  Travel_Frequently       1392  Research & Development
# 4      27          1      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          1  Travel_Frequently        884  Research & Development
# 1466   39          1      Travel_Rarely        613  Research & Development
# 1467   27          1      Travel_Rarely        155  Research & Development
# 1468   49          1  Travel_Frequently       1023                   Sales
# 1469   34          1      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_hr['Attrition'].sum() # Получается, у нас 1233 еще работают, а 237 из человек из датасета уволились.
# Out:
# 1233

# %%
df_hr['Gender'].sum() # Получается, у нас 882 мужчины и 588 женщин
# Out:
# 882

# %%
df_hr['Department'].unique() #если посмотреть, какие тут есть департаменты, можно сделать предположение о роде деятельности компании. Здесь представлено всего три, но по ним видно, что есть исследовательская деятельность
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df_hr['JobRole'].unique() # Посмотрим. какие представлены позиции
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
df_hr.describe() #Выведем основные статистики.
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.838776   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     1.000000   465.000000          2.000000     2.000000
# 50%      36.000000     1.000000   802.000000          7.000000     3.000000
# 75%      43.000000     1.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction       Gender  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769     0.600000
# ...

# %%
df_hr.corr() # И корреляции
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000   0.159205   0.010661         -0.001686
# Attrition                 0.159205   1.000000   0.056652         -0.077924
# DailyRate                 0.010661   0.056652   1.000000         -0.004985
# DistanceFromHome         -0.001686  -0.077924  -0.004985          1.000000
# Education                 0.208034   0.031373  -0.016806          0.021042
# EmployeeCount                  NaN        NaN        NaN               NaN
# EmployeeNumber           -0.010145   0.010577  -0.050990          0.032916
# EnvironmentSatisfaction   0.010146   0.103369   0.018355         -0.016075
# Gender                   -0.036311  -0.029453  -0.011716         -0.001851
# HourlyRate                0.024287   0.006846   0.023381          0.031131
# JobInvolvement            0.029820   0.130016   0.046135          0.008783
# ...

# %%
df_hr_g0 = df_hr[df_hr['Attrition'] == 0 ]
df_hr_g1 = df_hr[df_hr['Attrition'] == 1 ] #сделаем подвыборки по критерию ушел/остался

# %%
df_hr_g0.describe()
# Out:
#               Age  Attrition    DailyRate  DistanceFromHome   Education  \
# count  237.000000      237.0   237.000000        237.000000  237.000000
# mean    33.607595        0.0   750.362869         10.632911    2.839662
# std      9.689350        0.0   401.899519          8.452525    1.008244
# min     18.000000        0.0   103.000000          1.000000    1.000000
# 25%     28.000000        0.0   408.000000          3.000000    2.000000
# 50%     32.000000        0.0   699.000000          9.000000    3.000000
# 75%     39.000000        0.0  1092.000000         17.000000    4.000000
# max     58.000000        0.0  1496.000000         29.000000    5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction      Gender  \
# count          237.0      237.000000               237.000000  237.000000
# mean             1.0     1010.345992                 2.464135    0.632911
# std              0.0      580.750572                 1.169791    0.483031
# ...

# %%
df_hr_g1.describe()
# Out:
#                Age  Attrition    DailyRate  DistanceFromHome    Education  \
# count  1233.000000     1233.0  1233.000000       1233.000000  1233.000000
# mean     37.561233        1.0   812.504461          8.915653     2.927007
# std       8.888360        0.0   403.208379          8.012633     1.027002
# min      18.000000        1.0   102.000000          1.000000     1.000000
# 25%      31.000000        1.0   477.000000          2.000000     2.000000
# 50%      36.000000        1.0   817.000000          7.000000     3.000000
# 75%      43.000000        1.0  1176.000000         13.000000     4.000000
# max      60.000000        1.0  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction       Gender  \
# count         1233.0     1233.000000              1233.000000  1233.000000
# mean             1.0     1027.656123                 2.771290     0.593674
# std              0.0      606.217074                 1.071132     0.491346
# ...

# %%
df_hr_g0['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Laboratory Technician', 'Sales Representative',
#        'Research Scientist', 'Research Director', 'Human Resources',
#        'Healthcare Representative', 'Manufacturing Director', 'Manager'],
#       dtype=object)

# %%
sns.boxplot(x=df_hr["MonthlyIncome"]) #Визуализируем распределение зарплат
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
np.median(df_hr.MonthlyIncome)
# Out:
# 4919.0

# %%
df_hr_a0 = df_hr[df_hr['Department'] == 'Sales'] #Сделаем подвыборки по подразделениям
df_hr_a1 = df_hr[df_hr['Department'] == 'Research & Development']
df_hr_a2 = df_hr[df_hr['Department'] == 'Human Resources']

# %%
print("Count of Department = Sales\
 is {} and for Department = Research & Development \
      is {} and for Department = Human Resources is {}".format(len(df_hr_a0),
                                                               len(df_hr_a1),
                                                                len(df_hr_a2))) #Посмотрим, сколько в каждом из них человек
# Out:
# Count of Department = Sales is 446 and for Department = Research & Development       is 961 and for Department = Human Resources is 63

# %%
plt.hist(df_hr_a1['MonthlyIncome'], color = 'orange', edgecolor = 'black',
         bins = int(180/5))
plt.hist(df_hr_a0['MonthlyIncome'], color = 'darkblue', edgecolor = 'black',
         bins = int(180/5))
plt.hist(df_hr_a2['MonthlyIncome'], color = 'green', edgecolor = 'black',
         bins = int(180/5))
# Add labels
plt.title('Histogram of monthly income in 3 departments')
plt.xlabel('USD')
plt.ylabel('Amount of employees') # Посмотрим распределение зарплат в подразделении
# Out:
# Text(0, 0.5, 'Amount of employees')

# %%
sns.boxplot(x = df_hr_a2["MonthlyIncome"])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
np.median(df_hr_a2.MonthlyIncome)
# Out:
# 3886.0

# %%
df_hr['anomally_sal'] = np.where(
                            df_hr['MonthlyIncome'] > 
                            np.mean(df_hr.MonthlyIncome) + 3*np.std(df_hr.MonthlyIncome),                 
                            1, 0)

# %%
df_anomally_sal = df_hr[df_hr['anomally_sal'] == 1]

df_anomally_sal # В случае с уровнем дохода по всей компании, нет смысла искать аномалии, потому что большй разброс (их по сути нет). Пробую вывести аномальные значения для подгруппы HR (на графике видно, что они там есть)
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, anomally_sal]
# Index: []

# %%
df_hr[df_hr['Department'] == 'Human Resources'].loc[:, ('anomally_sal')] = np.where(
                            df_hr[df_hr['Department'] == 'Human Resources'].loc[:, ('MonthlyIncome')] > 
                            np.mean(df_hr[df_hr['Department'] == 'Human Resources'].loc[:, ('MonthlyIncome')]) + 3*np.std(df_hr[df_hr['Department'] == 'Human Resources'].loc[:, ('MonthlyIncome')]),                 
                            1, 0) #Пробую вывести аномальные значения для подгруппы HR (на графике видно, что они там есть). Пока не получилось!!!
# Out:
# C:\Users\annam\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
df_anomally_sal = df_hr[df_hr['anomally_sal'] == 1]

df_anomally_sal
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, anomally_sal]
# Index: []

# %%
np.median(df_hr_a0.MonthlyIncome)
# Out:
# 5754.5

# %%
np.median(df_hr_a1.MonthlyIncome)
# Out:
# 4374.0

# %%
sns.boxplot(x = df_hr_a0["MonthlyIncome"])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
sns.boxplot(x = df_hr_a1["MonthlyIncome"])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
#1. Набор содержит информацию о 1470 сотрудниках, часть из которых (237 человек) уже покинули компанию. Это понятно из столбца "attrition", который обозначает увольнение по прочим причинам (смерть, переезд).
#Исторические данные смешаны с фактическими данными о сотрудниках.
 
#Нам приведены данные о сотрудниках только трех департаментов:
#- Sales: 446
#- Research & Development: 961
#- Human Resources: 63

#Которые представлены следующими следующие должности:
#Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative, Research Director, Human Resources

#Но отсюда мы можем предположить, что компания занимается чем-то наукоёмким :) Эта информация может понадобиться при трактовке данных о зарплатах.

#2. В таблице вообще нет пропущенных значений. Значит, данные уже прошли чистку и готовы к обработке.

#3. В датасете есть стобцы, показывающие данные о субъективном благополучии сотрудников (EnvironmentSatisfaction, JobSatisfaction, RelationshipSatisfaction, WorkLifeBalance), в каждом из которых максимальное значение = 4.
#(2,72+-0,712) - EnvironmentSatisfaction
#(2,73+-1,11) - JobSatisfaction
#(2,72+-1,08) - RelationshipSatisfaction
#(2,76+-0,71) - WorkLifeBalance

#Если предположить, что при проведении опроса использовалась 4-балльная шкала, то, в среднем, работники удовлетворены условиями труда. Если 5-балльная, то есть вопросы.

#4. Каких-то интересных корреляций обнаружено не было.
#PercentSalaryHike и Performance rating связаны (r=0,77) - это хорошо :)
#Есть значимые положительные корреляции между отработанными годами и уровнем дохода и уровнем должности. Это сигнализирует о том, что оценка и продвижение в компании функционируют нормально. 

#4. Средний возраст уволившихся сотрудников - 33,6 лет и почти совпадает с медианой - 32.

#5.Наблюдения по уровню оплаты.
#Из представленных в датасете данных, наибольший интерес представляет столбец 'MonthlyIncome'.
#В целом, тут представлен большой разброс значений, 50% наблюдений лежит в пределах примерно [2900-8300], есть "перекос" в сторону более низких значений, медиана - 4919. 
#Значительное количество выбросов. 
#В департаменте HR самый низкий уровень зарплат. Там всего 5 выбросов (видимо, HRD и около того). Медиана распределения сильно смещена влево, медиана - 3886.
#Для сравнения, для сотрудников R&D медиана - 4374, а у сейлзов - 5754,5.
#В случае с уровнем дохода по всей компании, нет смысла искать аномалии, потому что слишком большой разброс
